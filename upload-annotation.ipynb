# %%
import requests
import base64
import xml.etree.ElementTree as ET
from IPython.display import IFrame
import json
import time

# %% [markdown]
# To use the IAW API, we firstly need to specify the API URL and token. The API token will be required in the Authorization header when sending requests

# %%
# The Base URL of IAW API.
iaw_api_base = 'https://iaw-server.ardc-hdcl-sia-iaw.cloud.edu.au/api'
# API token.
iaw_api_token = '3|dajsYsH0Dx87OXlAWk7T5ZDRJGgCMaV5WJhgKnth32114c9a'

# Set the headers
headers = {
    'Accept': 'application/json',
    'Authorization': f'Bearer {iaw_api_token}'
}

# %% [markdown]
# In the upcoming sections of the code, we will be defining some functions that will come in handy later on.

# %%
# Post a collection , Return the collection id ig created successfullly.
def create_collection(collection_name , collection_description):
   
    collection_data = {
        "name": collection_name, 
        "description": collection_description, 
    }
    
    url = f'{iaw_api_base}/collections' 
    response = requests.post(url, headers=headers, data=collection_data)

    if response.status_code == 200:  # Status 201 indicates successful creation
        new_collection = response.json()
        print(f'Collection created successfully with ID {new_collection["id"]}')
        return new_collection["id"]
    else:
        print('Failed to create collection')
        print(response.text)

# %%
# Creates an image. Upload the image under the current account
# The actual width and height of the image may differ from the dimensions provided in the XML file.
# This function retrieves the actual image dimensions from the response, calculates the width and height
# ratio, and uses these ratios to adjust the annotation coordinates accordingly
def post_image(name, path,  description , width , height):

    image_path = f'images/{path}'     
    # Read the image file in binary mode
    with open(image_path, 'rb') as image_file:
        encoded_image = base64.b64encode(image_file.read()).decode('utf-8')
    
    image_data = {
        "name": name, 
        "description": description,  
        "type" : "iiif",
        "source" : "this",
        "file": encoded_image  # Base64-encoded image content
    }

    
    url = f'{iaw_api_base}/images/local'
    response = requests.post(url, headers=headers, data=image_data)
    
    if response.status_code == 200:
        
        new_image = response.json()
            
        actual_width = new_image['width']
        actual_height = new_image['height']
        
        # Calculate the ratio
        width_ratio = float(actual_width) / float(width)
        height_ratio = float(actual_height) / float(height)
        
        print(f'Image created successfully with id {new_image["id"]}')
        return {
            "id": new_image["id"],
            "source": new_image["iiif_url"],
            "width_ratio": width_ratio,
            "height_ratio": height_ratio
        }
    else:
        print('Failed to create image')
        print(response.text)

# %%
# Post a image set to a given collection , add image to it
# After a collection is created successfully , we use the collection id to create a image set for it. And add all 
# the images we just uploaded to it.
def create_image_set_to_collection(collection_id ,image_ids ,name ,description , attribution):
    
    image_set_data = {
        "name": name,
        "description": description,
        "attribution": attribution,
        "published": True,
        "image_ids[]": image_ids 
    }
    
    url = f'{iaw_api_base}/collections/{collection_id}/image-sets' 
    response = requests.post(url, headers=headers, data=image_set_data)
    
    if response.status_code == 200:  
        new_image_set = response.json()
        print(f'Image set for collection {collection_id} created successfully with ID {new_image_set["id"]}')
        return new_image_set["id"]
    else:
        print('Failed to create image set')
        print(response.json())

# %%
# Now we add a annotation set to the image set we just created
def create_annotation_set(image_set_id , name, description ):
    
    annotation_set_data = {
        "name": name,
        "description": description,
        "image_set_id": image_set_id,
    }
    
    url = f'{iaw_api_base}/image-sets/{image_set_id}/annotation-sets' 
    response = requests.post(url, headers=headers, data=annotation_set_data)
    
    if response.status_code == 200: 
        new_annotation_set = response.json()
        print(f'Annotation set for image set ID {image_set_id} created successfully with ID {new_annotation_set["id"]}')
        return new_annotation_set["id"]
    else:
        print('Failed to create annotation set')
        print(response.json())

# %%
# Before we upload annotation. we will need to adjust the annotation location based on the ratios
def adjust_polygon_points(points, width_ratio, height_ratio):
    adjusted_points = []

    for point in points:
        x, y = map(float, point.split(","))
        adjusted_x = x * width_ratio
        adjusted_y = y * height_ratio
        adjusted_points.append(f"{adjusted_x},{adjusted_y}")

    return " ".join(adjusted_points)

# %%
# In the end we upload all the annotations for each image. 
# We will be using the 'points' attribute to create polygon for annotated text
def create_annotation(annotation_set_id, image_id, annotation_title, image_source, polygon):
    
    # Create the target as an object (dictionary in Python)
    target = {
        "source": image_source,
        "selector": {
            "type": "SvgSelector",
            "value": polygon
        }
    }
    
    field = {
        "title": {
            "en": {
                "values": [
                    annotation_title
                ]
            },
        }
    }

    # Prepare the annotation data
    annotation_data = {
        "annotation_type_id": 1,
        "annotation_set_id": annotation_set_id,
        "image_id": image_id,
        "target": target, 
        "fields" : field
    }


    url = f'{iaw_api_base}/annotation-sets/{annotation_set_id}/annotations'
    response = requests.post(url, headers=headers, json=annotation_data)
    
    # Handle the response
    if response.status_code == 200:
        new_annotation = response.json()
        print(f'Annotation for annotation set ID {annotation_set_id} created successfully with ID {new_annotation["id"]}')
    else:
        print('Failed to create annotation')
        print(response.json())

# %%
# After everything are created successfully, we Publish the image set and annotation set 
def publish_image_and_annotation_set(collection_id , image_set_id , annotation_set_id):
    
    publish_data = {
        "published": True,
    }
    
    url = f'{iaw_api_base}/collections/{collection_id}/image-sets/{image_set_id}' 
    response = requests.put(url, headers=headers, json=publish_data)
    
    if response.status_code == 200: 
        
        image_set_data = response.json()
        print(f'Image set published successfully')
        published_url = "https://iaw.ardc-hdcl-sia-iaw.cloud.edu.au/publications/image-sets/" + image_set_data['publication']['id']
        
        # Publish annotation set 
        url = f'{iaw_api_base}/image-sets/{image_set_id}/annotation-sets/{annotation_set_id}' 
        response = requests.put(url, headers=headers, json=publish_data)
        
        if response.status_code == 200: 
            print("Annotation set published successfully")
            return published_url
        else:
            print("Failed to publish annotation set")
    else:
        print('Failed to publish image set')
        print(response.json())

# %%
ns = {"ns": "http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15"}

def import_single_xml(xml_file):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Create collection
    collection_name = "Sample Collection"
    collection_description = " "
    collection_id = create_collection(collection_name , collection_description)
    
    # Upload image
    image_name = "0003_4966-P0000-000001-0010-010-001 page3"
    image_description = "0003_4966-P0000-000001-0010-010-001 page3"
    image = post_image( "Sample image", image_name + ".jpg", image_description , "500" , "500" )
    image_id = image["id"]
    image_source = image["source"]
    
    # Create image set and add image to it
    image_set_id = create_image_set_to_collection(collection_id , [image_id] , "Sample image" ,"Sample image" , " ")
    
    # Create annotation set
    annotation_set_id = create_annotation_set(image_set_id , "Text Annotation", " ")
    
    # Loop through each TextRegion
    for text_region in root.findall(".//ns:TextRegion", ns):
       
        # Loop through each TextLine within the current TextRegion
        for text_line in text_region.findall("ns:TextLine", ns):
                        
            # Add annotation from coordinates
            polygon =  "<svg><polygon points=\"" + text_line.find("ns:Coords", ns).attrib["points"] + "\"></polygon></svg>"
            unicode_text = text_line.find("ns:TextEquiv/ns:Unicode", ns).text.strip()
            create_annotation(annotation_set_id , image_id , unicode_text, image_source , polygon)
            
        
    # Publish image set and annotation set
    annotation_url = publish_image_and_annotation_set(collection_id, image_set_id , annotation_set_id)
      
    print(annotation_url)
    iframe = IFrame(src=annotation_url, width="100%", height="700px")
    display(iframe)

# Path to your XML file
xml_file_path = '0003_4966-P0000-000001-0010-010-001 page3.xml'

# Call the function with the file path
import_single_xml(xml_file_path)
# Out:
# Collection created successfully with ID 181
# Image created successfully with id 1633
# Image set for collection 181 created successfully with ID 655
# Annotation set for image set ID 655 created successfully with ID 652
# Annotation for annotation set ID 652 created successfully with ID 14061
# Annotation for annotation set ID 652 created successfully with ID 14062
# Annotation for annotation set ID 652 created successfully with ID 14063
# Annotation for annotation set ID 652 created successfully with ID 14064
# Annotation for annotation set ID 652 created successfully with ID 14065
# Annotation for annotation set ID 652 created successfully with ID 14066
# Annotation for annotation set ID 652 created successfully with ID 14067
# Annotation for annotation set ID 652 created successfully with ID 14068
# Annotation for annotation set ID 652 created successfully with ID 14069
# Annotation for annotation set ID 652 created successfully with ID 14070
# Annotation for annotation set ID 652 created successfully with ID 14071
# Annotation for annotation set ID 652 created successfully with ID 14072
# Annotation for annotation set ID 652 created successfully with ID 14073
# Annotation for annotation set ID 652 created successfully with ID 14074
# Annotation for annotation set ID 652 created successfully with ID 14075
# Annotation for annotation set ID 652 created successfully with ID 14076
# Annotation for annotation set ID 652 created successfully with ID 14077
# Annotation for annotation set ID 652 created successfully with ID 14078
# Annotation for annotation set ID 652 created successfully with ID 14079
# Annotation for annotation set ID 652 created successfully with ID 14080
# Annotation for annotation set ID 652 created successfully with ID 14081
# Annotation for annotation set ID 652 created successfully with ID 14082
# Annotation for annotation set ID 652 created successfully with ID 14083
# Annotation for annotation set ID 652 created successfully with ID 14084
# Annotation for annotation set ID 652 created successfully with ID 14085
# Annotation for annotation set ID 652 created successfully with ID 14086
# Annotation for annotation set ID 652 created successfully with ID 14087
# Image set published successfully
# Annotation set published successfully
# https://iaw.ardc-hdcl-sia-iaw.cloud.edu.au/publications/image-sets/01j8ntr4c2qmbw6yjc08774w23
#         <iframe
#             width="100%"
#             height="700px"
#             src="https://iaw.ardc-hdcl-sia-iaw.cloud.edu.au/publications/image-sets/01j8ntr4c2qmbw6yjc08774w23"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Define the XML namespace
ns = {'ns': 'http://www.tei-c.org/ns/1.0', 'xml': 'http://www.w3.org/XML/1998/namespace'}

def import_multiple_xml(xml_file):

    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Create collection
    collection_name = "TEI Transcription"
    collection_description = ""
    collection_id = create_collection(collection_name , collection_description)

    # Extract text annotations and populate the hashmap
    facs_text_map = {}  # id => annotated text
    text = root.find(".//ns:text", ns)
    if text is not None:
        for annotation_text in text.findall(".//ns:l", ns):
            facs_id = annotation_text.attrib.get("facs")
            text_content = annotation_text.text
            
            if facs_id and text_content:
                facs_text_map[facs_id] = text_content
    
    
    # Uoload all image and get image id
    image_info_map = {} 
    image_ids = []

    for facsimile in root.findall(".//ns:facsimile", ns): 
       
        image_id = facsimile.attrib.get("{http://www.w3.org/XML/1998/namespace}id")
        graphic = facsimile.find(".//ns:graphic", ns)    
        image_name = graphic.attrib.get("url")
        image_width = graphic.attrib.get("width").replace("px", "")
        image_height = graphic.attrib.get("height").replace("px", "")
        
        image = post_image(image_id , image_name.split('_', 1)[1] , image_name , image_width , image_height)
        image_info_map[image_name] = {
            'id' : image["id"],
            'source' : image["source"],
            'width_ratio': image["width_ratio"],
            'height_ratio': image["height_ratio"]
        }

        image_ids.append(image["id"])
    

    # Create one image set for ALL image
    image_set_id = create_image_set_to_collection(collection_id , image_ids , "Image Collections" , " " , " ")
    
    #Create annotation set for image set
    annotation_set_id = create_annotation_set(image_set_id , "Text annotation" , " ")
        

    for facsimile in root.findall(".//ns:facsimile", ns): 
        
        graphic = facsimile.find(".//ns:graphic", ns)
        image_name = graphic.attrib.get("url")
        image_info = image_info_map[image_name]

        print("-" * 50) 
       
        for zone in facsimile.findall(".//ns:zone[@rendition='Line']", ns):
           
            zone_id = zone.attrib.get("{http://www.w3.org/XML/1998/namespace}id")
            
            # Adjust the polygon points using the ratio
            adjusted_polygon = adjust_polygon_points(zone.attrib.get("points").split(" ") , image_info['width_ratio'], image_info['height_ratio'])
            polygon = f"<svg><polygon points=\"{adjusted_polygon}\"></polygon></svg>"
            

            # Check if the zone_id exists in the facs_text_map , get annotation text
            if f"#{zone_id}" in facs_text_map: 
                # Add annotation for each annotation set
                annotation_text = facs_text_map[f"#{zone_id}"]
                create_annotation(annotation_set_id , image_info['id'] , annotation_text, image_info['source'] , polygon)
                time.sleep(0.1)
                
    # Publish image set and annotation set
    annotation_url = publish_image_and_annotation_set(collection_id, image_set_id , annotation_set_id)
      
    print(annotation_url)
    iframe = IFrame(src=annotation_url, width="100%", height="700px")
    display(iframe)

# Path to your XML file
xml_file_path = '04965-P0000-000001-0010-010-002.xml'
# Call the function with the file path
import_multiple_xml(xml_file_path)
# Out:
# Collection created successfully with ID 182
# Image created successfully with id 1634
# Image created successfully with id 1635
# Image created successfully with id 1636
# Image created successfully with id 1637
# Image created successfully with id 1638
# Image created successfully with id 1639
# Image created successfully with id 1640
# Image created successfully with id 1641
# Image created successfully with id 1642
# Image created successfully with id 1643
# Image created successfully with id 1644
# Image created successfully with id 1645
# Image created successfully with id 1646
# Image created successfully with id 1647
# Image created successfully with id 1648
# Image created successfully with id 1649
# Image created successfully with id 1650
# Image created successfully with id 1651
# Image created successfully with id 1652
# Image created successfully with id 1653
# Image created successfully with id 1654
# Image created successfully with id 1655
# Image created successfully with id 1656
# Image created successfully with id 1657
# Image created successfully with id 1658
# Image created successfully with id 1659
# Image created successfully with id 1660
# Image created successfully with id 1661
# Image created successfully with id 1662
# Image created successfully with id 1663
# Image created successfully with id 1664
# Image created successfully with id 1665
# Image created successfully with id 1666
# Image created successfully with id 1667
# Image created successfully with id 1668
# Image created successfully with id 1669
# Image created successfully with id 1670
# Image created successfully with id 1671
# Image set for collection 182 created successfully with ID 656
# Annotation set for image set ID 656 created successfully with ID 653
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14088
# Annotation for annotation set ID 653 created successfully with ID 14089
# Annotation for annotation set ID 653 created successfully with ID 14090
# Annotation for annotation set ID 653 created successfully with ID 14091
# Annotation for annotation set ID 653 created successfully with ID 14092
# Annotation for annotation set ID 653 created successfully with ID 14093
# Annotation for annotation set ID 653 created successfully with ID 14094
# Annotation for annotation set ID 653 created successfully with ID 14095
# Annotation for annotation set ID 653 created successfully with ID 14096
# Annotation for annotation set ID 653 created successfully with ID 14097
# Annotation for annotation set ID 653 created successfully with ID 14098
# Annotation for annotation set ID 653 created successfully with ID 14099
# Annotation for annotation set ID 653 created successfully with ID 14100
# Annotation for annotation set ID 653 created successfully with ID 14101
# Annotation for annotation set ID 653 created successfully with ID 14102
# Annotation for annotation set ID 653 created successfully with ID 14103
# Annotation for annotation set ID 653 created successfully with ID 14104
# Annotation for annotation set ID 653 created successfully with ID 14105
# Annotation for annotation set ID 653 created successfully with ID 14106
# Annotation for annotation set ID 653 created successfully with ID 14107
# Annotation for annotation set ID 653 created successfully with ID 14108
# Annotation for annotation set ID 653 created successfully with ID 14109
# Annotation for annotation set ID 653 created successfully with ID 14110
# Annotation for annotation set ID 653 created successfully with ID 14111
# Annotation for annotation set ID 653 created successfully with ID 14112
# Annotation for annotation set ID 653 created successfully with ID 14113
# Annotation for annotation set ID 653 created successfully with ID 14114
# Annotation for annotation set ID 653 created successfully with ID 14115
# Annotation for annotation set ID 653 created successfully with ID 14116
# Annotation for annotation set ID 653 created successfully with ID 14117
# Annotation for annotation set ID 653 created successfully with ID 14118
# Annotation for annotation set ID 653 created successfully with ID 14119
# Annotation for annotation set ID 653 created successfully with ID 14120
# Annotation for annotation set ID 653 created successfully with ID 14121
# Annotation for annotation set ID 653 created successfully with ID 14122
# Annotation for annotation set ID 653 created successfully with ID 14123
# Annotation for annotation set ID 653 created successfully with ID 14124
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14125
# Annotation for annotation set ID 653 created successfully with ID 14126
# Annotation for annotation set ID 653 created successfully with ID 14127
# Annotation for annotation set ID 653 created successfully with ID 14128
# Annotation for annotation set ID 653 created successfully with ID 14129
# Annotation for annotation set ID 653 created successfully with ID 14130
# Annotation for annotation set ID 653 created successfully with ID 14131
# Annotation for annotation set ID 653 created successfully with ID 14132
# Annotation for annotation set ID 653 created successfully with ID 14133
# Annotation for annotation set ID 653 created successfully with ID 14134
# Annotation for annotation set ID 653 created successfully with ID 14135
# Annotation for annotation set ID 653 created successfully with ID 14136
# Annotation for annotation set ID 653 created successfully with ID 14137
# Annotation for annotation set ID 653 created successfully with ID 14138
# Annotation for annotation set ID 653 created successfully with ID 14139
# Annotation for annotation set ID 653 created successfully with ID 14140
# Annotation for annotation set ID 653 created successfully with ID 14141
# Annotation for annotation set ID 653 created successfully with ID 14142
# Annotation for annotation set ID 653 created successfully with ID 14143
# Annotation for annotation set ID 653 created successfully with ID 14144
# Annotation for annotation set ID 653 created successfully with ID 14145
# Annotation for annotation set ID 653 created successfully with ID 14146
# Annotation for annotation set ID 653 created successfully with ID 14147
# Annotation for annotation set ID 653 created successfully with ID 14148
# Annotation for annotation set ID 653 created successfully with ID 14149
# Annotation for annotation set ID 653 created successfully with ID 14150
# Annotation for annotation set ID 653 created successfully with ID 14151
# Annotation for annotation set ID 653 created successfully with ID 14152
# Annotation for annotation set ID 653 created successfully with ID 14153
# Annotation for annotation set ID 653 created successfully with ID 14154
# Annotation for annotation set ID 653 created successfully with ID 14155
# Annotation for annotation set ID 653 created successfully with ID 14156
# Annotation for annotation set ID 653 created successfully with ID 14157
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14158
# Annotation for annotation set ID 653 created successfully with ID 14159
# Annotation for annotation set ID 653 created successfully with ID 14160
# Annotation for annotation set ID 653 created successfully with ID 14161
# Annotation for annotation set ID 653 created successfully with ID 14162
# Annotation for annotation set ID 653 created successfully with ID 14163
# Annotation for annotation set ID 653 created successfully with ID 14164
# Annotation for annotation set ID 653 created successfully with ID 14165
# Annotation for annotation set ID 653 created successfully with ID 14166
# Annotation for annotation set ID 653 created successfully with ID 14167
# Annotation for annotation set ID 653 created successfully with ID 14168
# Annotation for annotation set ID 653 created successfully with ID 14169
# Annotation for annotation set ID 653 created successfully with ID 14170
# Annotation for annotation set ID 653 created successfully with ID 14171
# Annotation for annotation set ID 653 created successfully with ID 14172
# Annotation for annotation set ID 653 created successfully with ID 14173
# Annotation for annotation set ID 653 created successfully with ID 14174
# Annotation for annotation set ID 653 created successfully with ID 14175
# Annotation for annotation set ID 653 created successfully with ID 14176
# Annotation for annotation set ID 653 created successfully with ID 14177
# Annotation for annotation set ID 653 created successfully with ID 14178
# Annotation for annotation set ID 653 created successfully with ID 14179
# Annotation for annotation set ID 653 created successfully with ID 14180
# Annotation for annotation set ID 653 created successfully with ID 14181
# Annotation for annotation set ID 653 created successfully with ID 14182
# Annotation for annotation set ID 653 created successfully with ID 14183
# Annotation for annotation set ID 653 created successfully with ID 14184
# Annotation for annotation set ID 653 created successfully with ID 14185
# Annotation for annotation set ID 653 created successfully with ID 14186
# Annotation for annotation set ID 653 created successfully with ID 14187
# Annotation for annotation set ID 653 created successfully with ID 14188
# Annotation for annotation set ID 653 created successfully with ID 14189
# Annotation for annotation set ID 653 created successfully with ID 14190
# Annotation for annotation set ID 653 created successfully with ID 14191
# Annotation for annotation set ID 653 created successfully with ID 14192
# Annotation for annotation set ID 653 created successfully with ID 14193
# Annotation for annotation set ID 653 created successfully with ID 14194
# Annotation for annotation set ID 653 created successfully with ID 14195
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14196
# Annotation for annotation set ID 653 created successfully with ID 14197
# Annotation for annotation set ID 653 created successfully with ID 14198
# Annotation for annotation set ID 653 created successfully with ID 14199
# Annotation for annotation set ID 653 created successfully with ID 14200
# Annotation for annotation set ID 653 created successfully with ID 14201
# Annotation for annotation set ID 653 created successfully with ID 14202
# Annotation for annotation set ID 653 created successfully with ID 14203
# Annotation for annotation set ID 653 created successfully with ID 14204
# Annotation for annotation set ID 653 created successfully with ID 14205
# Annotation for annotation set ID 653 created successfully with ID 14206
# Annotation for annotation set ID 653 created successfully with ID 14207
# Annotation for annotation set ID 653 created successfully with ID 14208
# Annotation for annotation set ID 653 created successfully with ID 14209
# Annotation for annotation set ID 653 created successfully with ID 14210
# Annotation for annotation set ID 653 created successfully with ID 14211
# Annotation for annotation set ID 653 created successfully with ID 14212
# Annotation for annotation set ID 653 created successfully with ID 14213
# Annotation for annotation set ID 653 created successfully with ID 14214
# Annotation for annotation set ID 653 created successfully with ID 14215
# Annotation for annotation set ID 653 created successfully with ID 14216
# Annotation for annotation set ID 653 created successfully with ID 14217
# Annotation for annotation set ID 653 created successfully with ID 14218
# Annotation for annotation set ID 653 created successfully with ID 14219
# Annotation for annotation set ID 653 created successfully with ID 14220
# Annotation for annotation set ID 653 created successfully with ID 14221
# Annotation for annotation set ID 653 created successfully with ID 14222
# Annotation for annotation set ID 653 created successfully with ID 14223
# Annotation for annotation set ID 653 created successfully with ID 14224
# Annotation for annotation set ID 653 created successfully with ID 14225
# Annotation for annotation set ID 653 created successfully with ID 14226
# Annotation for annotation set ID 653 created successfully with ID 14227
# Annotation for annotation set ID 653 created successfully with ID 14228
# Annotation for annotation set ID 653 created successfully with ID 14229
# Annotation for annotation set ID 653 created successfully with ID 14230
# Annotation for annotation set ID 653 created successfully with ID 14231
# Annotation for annotation set ID 653 created successfully with ID 14232
# Annotation for annotation set ID 653 created successfully with ID 14233
# Annotation for annotation set ID 653 created successfully with ID 14234
# Annotation for annotation set ID 653 created successfully with ID 14235
# Annotation for annotation set ID 653 created successfully with ID 14236
# Annotation for annotation set ID 653 created successfully with ID 14237
# Annotation for annotation set ID 653 created successfully with ID 14238
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14239
# Annotation for annotation set ID 653 created successfully with ID 14240
# Annotation for annotation set ID 653 created successfully with ID 14241
# Annotation for annotation set ID 653 created successfully with ID 14242
# Annotation for annotation set ID 653 created successfully with ID 14243
# Annotation for annotation set ID 653 created successfully with ID 14244
# Annotation for annotation set ID 653 created successfully with ID 14245
# Annotation for annotation set ID 653 created successfully with ID 14246
# Annotation for annotation set ID 653 created successfully with ID 14247
# Annotation for annotation set ID 653 created successfully with ID 14248
# Annotation for annotation set ID 653 created successfully with ID 14249
# Annotation for annotation set ID 653 created successfully with ID 14250
# Annotation for annotation set ID 653 created successfully with ID 14251
# Annotation for annotation set ID 653 created successfully with ID 14252
# Annotation for annotation set ID 653 created successfully with ID 14253
# Annotation for annotation set ID 653 created successfully with ID 14254
# Annotation for annotation set ID 653 created successfully with ID 14255
# Annotation for annotation set ID 653 created successfully with ID 14256
# Annotation for annotation set ID 653 created successfully with ID 14257
# Annotation for annotation set ID 653 created successfully with ID 14258
# Annotation for annotation set ID 653 created successfully with ID 14259
# Annotation for annotation set ID 653 created successfully with ID 14260
# Annotation for annotation set ID 653 created successfully with ID 14261
# Annotation for annotation set ID 653 created successfully with ID 14262
# Annotation for annotation set ID 653 created successfully with ID 14263
# Annotation for annotation set ID 653 created successfully with ID 14264
# Annotation for annotation set ID 653 created successfully with ID 14265
# Annotation for annotation set ID 653 created successfully with ID 14266
# Annotation for annotation set ID 653 created successfully with ID 14267
# Annotation for annotation set ID 653 created successfully with ID 14268
# Annotation for annotation set ID 653 created successfully with ID 14269
# Annotation for annotation set ID 653 created successfully with ID 14270
# Annotation for annotation set ID 653 created successfully with ID 14271
# Annotation for annotation set ID 653 created successfully with ID 14272
# Annotation for annotation set ID 653 created successfully with ID 14273
# Annotation for annotation set ID 653 created successfully with ID 14274
# Annotation for annotation set ID 653 created successfully with ID 14275
# Annotation for annotation set ID 653 created successfully with ID 14276
# Annotation for annotation set ID 653 created successfully with ID 14277
# Annotation for annotation set ID 653 created successfully with ID 14278
# Annotation for annotation set ID 653 created successfully with ID 14279
# Annotation for annotation set ID 653 created successfully with ID 14280
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14281
# Annotation for annotation set ID 653 created successfully with ID 14282
# Annotation for annotation set ID 653 created successfully with ID 14283
# Annotation for annotation set ID 653 created successfully with ID 14284
# Annotation for annotation set ID 653 created successfully with ID 14285
# Annotation for annotation set ID 653 created successfully with ID 14286
# Annotation for annotation set ID 653 created successfully with ID 14287
# Annotation for annotation set ID 653 created successfully with ID 14288
# Annotation for annotation set ID 653 created successfully with ID 14289
# Annotation for annotation set ID 653 created successfully with ID 14290
# Annotation for annotation set ID 653 created successfully with ID 14291
# Annotation for annotation set ID 653 created successfully with ID 14292
# Annotation for annotation set ID 653 created successfully with ID 14293
# Annotation for annotation set ID 653 created successfully with ID 14294
# Annotation for annotation set ID 653 created successfully with ID 14295
# Annotation for annotation set ID 653 created successfully with ID 14296
# Annotation for annotation set ID 653 created successfully with ID 14297
# Annotation for annotation set ID 653 created successfully with ID 14298
# Annotation for annotation set ID 653 created successfully with ID 14299
# Annotation for annotation set ID 653 created successfully with ID 14300
# Annotation for annotation set ID 653 created successfully with ID 14301
# Annotation for annotation set ID 653 created successfully with ID 14302
# Annotation for annotation set ID 653 created successfully with ID 14303
# Annotation for annotation set ID 653 created successfully with ID 14304
# Annotation for annotation set ID 653 created successfully with ID 14305
# Annotation for annotation set ID 653 created successfully with ID 14306
# Annotation for annotation set ID 653 created successfully with ID 14307
# Annotation for annotation set ID 653 created successfully with ID 14308
# Annotation for annotation set ID 653 created successfully with ID 14309
# Annotation for annotation set ID 653 created successfully with ID 14310
# Annotation for annotation set ID 653 created successfully with ID 14311
# Annotation for annotation set ID 653 created successfully with ID 14312
# Annotation for annotation set ID 653 created successfully with ID 14313
# Annotation for annotation set ID 653 created successfully with ID 14314
# Annotation for annotation set ID 653 created successfully with ID 14315
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14316
# Annotation for annotation set ID 653 created successfully with ID 14317
# Annotation for annotation set ID 653 created successfully with ID 14318
# Annotation for annotation set ID 653 created successfully with ID 14319
# Annotation for annotation set ID 653 created successfully with ID 14320
# Annotation for annotation set ID 653 created successfully with ID 14321
# Annotation for annotation set ID 653 created successfully with ID 14322
# Annotation for annotation set ID 653 created successfully with ID 14323
# Annotation for annotation set ID 653 created successfully with ID 14324
# Annotation for annotation set ID 653 created successfully with ID 14325
# Annotation for annotation set ID 653 created successfully with ID 14326
# Annotation for annotation set ID 653 created successfully with ID 14327
# Annotation for annotation set ID 653 created successfully with ID 14328
# Annotation for annotation set ID 653 created successfully with ID 14329
# Annotation for annotation set ID 653 created successfully with ID 14330
# Annotation for annotation set ID 653 created successfully with ID 14331
# Annotation for annotation set ID 653 created successfully with ID 14332
# Annotation for annotation set ID 653 created successfully with ID 14333
# Annotation for annotation set ID 653 created successfully with ID 14334
# Annotation for annotation set ID 653 created successfully with ID 14335
# Annotation for annotation set ID 653 created successfully with ID 14336
# Annotation for annotation set ID 653 created successfully with ID 14337
# Annotation for annotation set ID 653 created successfully with ID 14338
# Annotation for annotation set ID 653 created successfully with ID 14339
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14340
# Annotation for annotation set ID 653 created successfully with ID 14341
# Annotation for annotation set ID 653 created successfully with ID 14342
# Annotation for annotation set ID 653 created successfully with ID 14343
# Annotation for annotation set ID 653 created successfully with ID 14344
# Annotation for annotation set ID 653 created successfully with ID 14345
# Annotation for annotation set ID 653 created successfully with ID 14346
# Annotation for annotation set ID 653 created successfully with ID 14347
# Annotation for annotation set ID 653 created successfully with ID 14348
# Annotation for annotation set ID 653 created successfully with ID 14349
# Annotation for annotation set ID 653 created successfully with ID 14350
# Annotation for annotation set ID 653 created successfully with ID 14351
# Annotation for annotation set ID 653 created successfully with ID 14352
# Annotation for annotation set ID 653 created successfully with ID 14353
# Annotation for annotation set ID 653 created successfully with ID 14354
# Annotation for annotation set ID 653 created successfully with ID 14355
# Annotation for annotation set ID 653 created successfully with ID 14356
# Annotation for annotation set ID 653 created successfully with ID 14357
# Annotation for annotation set ID 653 created successfully with ID 14358
# Annotation for annotation set ID 653 created successfully with ID 14359
# Annotation for annotation set ID 653 created successfully with ID 14360
# Annotation for annotation set ID 653 created successfully with ID 14361
# Annotation for annotation set ID 653 created successfully with ID 14362
# Annotation for annotation set ID 653 created successfully with ID 14363
# Annotation for annotation set ID 653 created successfully with ID 14364
# Annotation for annotation set ID 653 created successfully with ID 14365
# Annotation for annotation set ID 653 created successfully with ID 14366
# Annotation for annotation set ID 653 created successfully with ID 14367
# Annotation for annotation set ID 653 created successfully with ID 14368
# Annotation for annotation set ID 653 created successfully with ID 14369
# Annotation for annotation set ID 653 created successfully with ID 14370
# Annotation for annotation set ID 653 created successfully with ID 14371
# Annotation for annotation set ID 653 created successfully with ID 14372
# Annotation for annotation set ID 653 created successfully with ID 14373
# Annotation for annotation set ID 653 created successfully with ID 14374
# Annotation for annotation set ID 653 created successfully with ID 14375
# Annotation for annotation set ID 653 created successfully with ID 14376
# Annotation for annotation set ID 653 created successfully with ID 14377
# Annotation for annotation set ID 653 created successfully with ID 14378
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14379
# Annotation for annotation set ID 653 created successfully with ID 14380
# Annotation for annotation set ID 653 created successfully with ID 14381
# Annotation for annotation set ID 653 created successfully with ID 14382
# Annotation for annotation set ID 653 created successfully with ID 14383
# Annotation for annotation set ID 653 created successfully with ID 14384
# Annotation for annotation set ID 653 created successfully with ID 14385
# Annotation for annotation set ID 653 created successfully with ID 14386
# Annotation for annotation set ID 653 created successfully with ID 14387
# Annotation for annotation set ID 653 created successfully with ID 14388
# Annotation for annotation set ID 653 created successfully with ID 14389
# Annotation for annotation set ID 653 created successfully with ID 14390
# Annotation for annotation set ID 653 created successfully with ID 14391
# Annotation for annotation set ID 653 created successfully with ID 14392
# Annotation for annotation set ID 653 created successfully with ID 14393
# Annotation for annotation set ID 653 created successfully with ID 14394
# Annotation for annotation set ID 653 created successfully with ID 14395
# Annotation for annotation set ID 653 created successfully with ID 14396
# Annotation for annotation set ID 653 created successfully with ID 14397
# Annotation for annotation set ID 653 created successfully with ID 14398
# Annotation for annotation set ID 653 created successfully with ID 14399
# Annotation for annotation set ID 653 created successfully with ID 14400
# Annotation for annotation set ID 653 created successfully with ID 14401
# Annotation for annotation set ID 653 created successfully with ID 14402
# Annotation for annotation set ID 653 created successfully with ID 14403
# Annotation for annotation set ID 653 created successfully with ID 14404
# Annotation for annotation set ID 653 created successfully with ID 14405
# Annotation for annotation set ID 653 created successfully with ID 14406
# Annotation for annotation set ID 653 created successfully with ID 14407
# Annotation for annotation set ID 653 created successfully with ID 14408
# Annotation for annotation set ID 653 created successfully with ID 14409
# Annotation for annotation set ID 653 created successfully with ID 14410
# Annotation for annotation set ID 653 created successfully with ID 14411
# Annotation for annotation set ID 653 created successfully with ID 14412
# Annotation for annotation set ID 653 created successfully with ID 14413
# Annotation for annotation set ID 653 created successfully with ID 14414
# Annotation for annotation set ID 653 created successfully with ID 14415
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14416
# Annotation for annotation set ID 653 created successfully with ID 14417
# Annotation for annotation set ID 653 created successfully with ID 14418
# Annotation for annotation set ID 653 created successfully with ID 14419
# Annotation for annotation set ID 653 created successfully with ID 14420
# Annotation for annotation set ID 653 created successfully with ID 14421
# Annotation for annotation set ID 653 created successfully with ID 14422
# Annotation for annotation set ID 653 created successfully with ID 14423
# Annotation for annotation set ID 653 created successfully with ID 14424
# Annotation for annotation set ID 653 created successfully with ID 14425
# Annotation for annotation set ID 653 created successfully with ID 14426
# Annotation for annotation set ID 653 created successfully with ID 14427
# Annotation for annotation set ID 653 created successfully with ID 14428
# Annotation for annotation set ID 653 created successfully with ID 14429
# Annotation for annotation set ID 653 created successfully with ID 14430
# Annotation for annotation set ID 653 created successfully with ID 14431
# Annotation for annotation set ID 653 created successfully with ID 14432
# Annotation for annotation set ID 653 created successfully with ID 14433
# Annotation for annotation set ID 653 created successfully with ID 14434
# Annotation for annotation set ID 653 created successfully with ID 14435
# Annotation for annotation set ID 653 created successfully with ID 14436
# Annotation for annotation set ID 653 created successfully with ID 14437
# Annotation for annotation set ID 653 created successfully with ID 14438
# Annotation for annotation set ID 653 created successfully with ID 14439
# Annotation for annotation set ID 653 created successfully with ID 14440
# Annotation for annotation set ID 653 created successfully with ID 14441
# Annotation for annotation set ID 653 created successfully with ID 14442
# Annotation for annotation set ID 653 created successfully with ID 14443
# Annotation for annotation set ID 653 created successfully with ID 14444
# Annotation for annotation set ID 653 created successfully with ID 14445
# Annotation for annotation set ID 653 created successfully with ID 14446
# Annotation for annotation set ID 653 created successfully with ID 14447
# Annotation for annotation set ID 653 created successfully with ID 14448
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14449
# Annotation for annotation set ID 653 created successfully with ID 14450
# Annotation for annotation set ID 653 created successfully with ID 14451
# Annotation for annotation set ID 653 created successfully with ID 14452
# Annotation for annotation set ID 653 created successfully with ID 14453
# Annotation for annotation set ID 653 created successfully with ID 14454
# Annotation for annotation set ID 653 created successfully with ID 14455
# Annotation for annotation set ID 653 created successfully with ID 14456
# Annotation for annotation set ID 653 created successfully with ID 14457
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14458
# Annotation for annotation set ID 653 created successfully with ID 14459
# Annotation for annotation set ID 653 created successfully with ID 14460
# Annotation for annotation set ID 653 created successfully with ID 14461
# Annotation for annotation set ID 653 created successfully with ID 14462
# Annotation for annotation set ID 653 created successfully with ID 14463
# Annotation for annotation set ID 653 created successfully with ID 14464
# Annotation for annotation set ID 653 created successfully with ID 14465
# Annotation for annotation set ID 653 created successfully with ID 14466
# Annotation for annotation set ID 653 created successfully with ID 14467
# Annotation for annotation set ID 653 created successfully with ID 14468
# Annotation for annotation set ID 653 created successfully with ID 14469
# Annotation for annotation set ID 653 created successfully with ID 14470
# Annotation for annotation set ID 653 created successfully with ID 14471
# Annotation for annotation set ID 653 created successfully with ID 14472
# Annotation for annotation set ID 653 created successfully with ID 14473
# Annotation for annotation set ID 653 created successfully with ID 14474
# Annotation for annotation set ID 653 created successfully with ID 14475
# Annotation for annotation set ID 653 created successfully with ID 14476
# Annotation for annotation set ID 653 created successfully with ID 14477
# Annotation for annotation set ID 653 created successfully with ID 14478
# Annotation for annotation set ID 653 created successfully with ID 14479
# Annotation for annotation set ID 653 created successfully with ID 14480
# Annotation for annotation set ID 653 created successfully with ID 14481
# Annotation for annotation set ID 653 created successfully with ID 14482
# Annotation for annotation set ID 653 created successfully with ID 14483
# Annotation for annotation set ID 653 created successfully with ID 14484
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14485
# Annotation for annotation set ID 653 created successfully with ID 14486
# Annotation for annotation set ID 653 created successfully with ID 14487
# Annotation for annotation set ID 653 created successfully with ID 14488
# Annotation for annotation set ID 653 created successfully with ID 14489
# Annotation for annotation set ID 653 created successfully with ID 14490
# Annotation for annotation set ID 653 created successfully with ID 14491
# Annotation for annotation set ID 653 created successfully with ID 14492
# Annotation for annotation set ID 653 created successfully with ID 14493
# Annotation for annotation set ID 653 created successfully with ID 14494
# Annotation for annotation set ID 653 created successfully with ID 14495
# Annotation for annotation set ID 653 created successfully with ID 14496
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14497
# Annotation for annotation set ID 653 created successfully with ID 14498
# Annotation for annotation set ID 653 created successfully with ID 14499
# Annotation for annotation set ID 653 created successfully with ID 14500
# Annotation for annotation set ID 653 created successfully with ID 14501
# Annotation for annotation set ID 653 created successfully with ID 14502
# Annotation for annotation set ID 653 created successfully with ID 14503
# Annotation for annotation set ID 653 created successfully with ID 14504
# Annotation for annotation set ID 653 created successfully with ID 14505
# Annotation for annotation set ID 653 created successfully with ID 14506
# Annotation for annotation set ID 653 created successfully with ID 14507
# Annotation for annotation set ID 653 created successfully with ID 14508
# Annotation for annotation set ID 653 created successfully with ID 14509
# Annotation for annotation set ID 653 created successfully with ID 14510
# Annotation for annotation set ID 653 created successfully with ID 14511
# Annotation for annotation set ID 653 created successfully with ID 14512
# Annotation for annotation set ID 653 created successfully with ID 14513
# Annotation for annotation set ID 653 created successfully with ID 14514
# Annotation for annotation set ID 653 created successfully with ID 14515
# Annotation for annotation set ID 653 created successfully with ID 14516
# Annotation for annotation set ID 653 created successfully with ID 14517
# Annotation for annotation set ID 653 created successfully with ID 14518
# Annotation for annotation set ID 653 created successfully with ID 14519
# Annotation for annotation set ID 653 created successfully with ID 14520
# Annotation for annotation set ID 653 created successfully with ID 14521
# Annotation for annotation set ID 653 created successfully with ID 14522
# Annotation for annotation set ID 653 created successfully with ID 14523
# Annotation for annotation set ID 653 created successfully with ID 14524
# Annotation for annotation set ID 653 created successfully with ID 14525
# Annotation for annotation set ID 653 created successfully with ID 14526
# Annotation for annotation set ID 653 created successfully with ID 14527
# Annotation for annotation set ID 653 created successfully with ID 14528
# Annotation for annotation set ID 653 created successfully with ID 14529
# Annotation for annotation set ID 653 created successfully with ID 14530
# Annotation for annotation set ID 653 created successfully with ID 14531
# Annotation for annotation set ID 653 created successfully with ID 14532
# Annotation for annotation set ID 653 created successfully with ID 14533
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14534
# Annotation for annotation set ID 653 created successfully with ID 14535
# Annotation for annotation set ID 653 created successfully with ID 14536
# Annotation for annotation set ID 653 created successfully with ID 14537
# Annotation for annotation set ID 653 created successfully with ID 14538
# Annotation for annotation set ID 653 created successfully with ID 14539
# Annotation for annotation set ID 653 created successfully with ID 14540
# Annotation for annotation set ID 653 created successfully with ID 14541
# Annotation for annotation set ID 653 created successfully with ID 14542
# Annotation for annotation set ID 653 created successfully with ID 14543
# Annotation for annotation set ID 653 created successfully with ID 14544
# Annotation for annotation set ID 653 created successfully with ID 14545
# Annotation for annotation set ID 653 created successfully with ID 14546
# Annotation for annotation set ID 653 created successfully with ID 14547
# Annotation for annotation set ID 653 created successfully with ID 14548
# Annotation for annotation set ID 653 created successfully with ID 14549
# Annotation for annotation set ID 653 created successfully with ID 14550
# Annotation for annotation set ID 653 created successfully with ID 14551
# Annotation for annotation set ID 653 created successfully with ID 14552
# Annotation for annotation set ID 653 created successfully with ID 14553
# Annotation for annotation set ID 653 created successfully with ID 14554
# Annotation for annotation set ID 653 created successfully with ID 14555
# Annotation for annotation set ID 653 created successfully with ID 14556
# Annotation for annotation set ID 653 created successfully with ID 14557
# Annotation for annotation set ID 653 created successfully with ID 14558
# Annotation for annotation set ID 653 created successfully with ID 14559
# Annotation for annotation set ID 653 created successfully with ID 14560
# Annotation for annotation set ID 653 created successfully with ID 14561
# Annotation for annotation set ID 653 created successfully with ID 14562
# Annotation for annotation set ID 653 created successfully with ID 14563
# Annotation for annotation set ID 653 created successfully with ID 14564
# Annotation for annotation set ID 653 created successfully with ID 14565
# Annotation for annotation set ID 653 created successfully with ID 14566
# Annotation for annotation set ID 653 created successfully with ID 14567
# Annotation for annotation set ID 653 created successfully with ID 14568
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14569
# Annotation for annotation set ID 653 created successfully with ID 14570
# Annotation for annotation set ID 653 created successfully with ID 14571
# Annotation for annotation set ID 653 created successfully with ID 14572
# Annotation for annotation set ID 653 created successfully with ID 14573
# Annotation for annotation set ID 653 created successfully with ID 14574
# Annotation for annotation set ID 653 created successfully with ID 14575
# Annotation for annotation set ID 653 created successfully with ID 14576
# Annotation for annotation set ID 653 created successfully with ID 14577
# Annotation for annotation set ID 653 created successfully with ID 14578
# Annotation for annotation set ID 653 created successfully with ID 14579
# Annotation for annotation set ID 653 created successfully with ID 14580
# Annotation for annotation set ID 653 created successfully with ID 14581
# Annotation for annotation set ID 653 created successfully with ID 14582
# Annotation for annotation set ID 653 created successfully with ID 14583
# Annotation for annotation set ID 653 created successfully with ID 14584
# Annotation for annotation set ID 653 created successfully with ID 14585
# Annotation for annotation set ID 653 created successfully with ID 14586
# Annotation for annotation set ID 653 created successfully with ID 14587
# Annotation for annotation set ID 653 created successfully with ID 14588
# Annotation for annotation set ID 653 created successfully with ID 14589
# Annotation for annotation set ID 653 created successfully with ID 14590
# Annotation for annotation set ID 653 created successfully with ID 14591
# Annotation for annotation set ID 653 created successfully with ID 14592
# Annotation for annotation set ID 653 created successfully with ID 14593
# Annotation for annotation set ID 653 created successfully with ID 14594
# Annotation for annotation set ID 653 created successfully with ID 14595
# Annotation for annotation set ID 653 created successfully with ID 14596
# Annotation for annotation set ID 653 created successfully with ID 14597
# Annotation for annotation set ID 653 created successfully with ID 14598
# Annotation for annotation set ID 653 created successfully with ID 14599
# Annotation for annotation set ID 653 created successfully with ID 14600
# Annotation for annotation set ID 653 created successfully with ID 14601
# Annotation for annotation set ID 653 created successfully with ID 14602
# Annotation for annotation set ID 653 created successfully with ID 14603
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14604
# Annotation for annotation set ID 653 created successfully with ID 14605
# Annotation for annotation set ID 653 created successfully with ID 14606
# Annotation for annotation set ID 653 created successfully with ID 14607
# Annotation for annotation set ID 653 created successfully with ID 14608
# Annotation for annotation set ID 653 created successfully with ID 14609
# Annotation for annotation set ID 653 created successfully with ID 14610
# Annotation for annotation set ID 653 created successfully with ID 14611
# Annotation for annotation set ID 653 created successfully with ID 14612
# Annotation for annotation set ID 653 created successfully with ID 14613
# Annotation for annotation set ID 653 created successfully with ID 14614
# Annotation for annotation set ID 653 created successfully with ID 14615
# Annotation for annotation set ID 653 created successfully with ID 14616
# Annotation for annotation set ID 653 created successfully with ID 14617
# Annotation for annotation set ID 653 created successfully with ID 14618
# Annotation for annotation set ID 653 created successfully with ID 14619
# Annotation for annotation set ID 653 created successfully with ID 14620
# Annotation for annotation set ID 653 created successfully with ID 14621
# Annotation for annotation set ID 653 created successfully with ID 14622
# Annotation for annotation set ID 653 created successfully with ID 14623
# Annotation for annotation set ID 653 created successfully with ID 14624
# Annotation for annotation set ID 653 created successfully with ID 14625
# Annotation for annotation set ID 653 created successfully with ID 14626
# Annotation for annotation set ID 653 created successfully with ID 14627
# Annotation for annotation set ID 653 created successfully with ID 14628
# Annotation for annotation set ID 653 created successfully with ID 14629
# Annotation for annotation set ID 653 created successfully with ID 14630
# Annotation for annotation set ID 653 created successfully with ID 14631
# Annotation for annotation set ID 653 created successfully with ID 14632
# Annotation for annotation set ID 653 created successfully with ID 14633
# Annotation for annotation set ID 653 created successfully with ID 14634
# Annotation for annotation set ID 653 created successfully with ID 14635
# Annotation for annotation set ID 653 created successfully with ID 14636
# Annotation for annotation set ID 653 created successfully with ID 14637
# Annotation for annotation set ID 653 created successfully with ID 14638
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14639
# Annotation for annotation set ID 653 created successfully with ID 14640
# Annotation for annotation set ID 653 created successfully with ID 14641
# Annotation for annotation set ID 653 created successfully with ID 14642
# Annotation for annotation set ID 653 created successfully with ID 14643
# Annotation for annotation set ID 653 created successfully with ID 14644
# Annotation for annotation set ID 653 created successfully with ID 14645
# Annotation for annotation set ID 653 created successfully with ID 14646
# Annotation for annotation set ID 653 created successfully with ID 14647
# Annotation for annotation set ID 653 created successfully with ID 14648
# Annotation for annotation set ID 653 created successfully with ID 14649
# Annotation for annotation set ID 653 created successfully with ID 14650
# Annotation for annotation set ID 653 created successfully with ID 14651
# Annotation for annotation set ID 653 created successfully with ID 14652
# Annotation for annotation set ID 653 created successfully with ID 14653
# Annotation for annotation set ID 653 created successfully with ID 14654
# Annotation for annotation set ID 653 created successfully with ID 14655
# Annotation for annotation set ID 653 created successfully with ID 14656
# Annotation for annotation set ID 653 created successfully with ID 14657
# Annotation for annotation set ID 653 created successfully with ID 14658
# Annotation for annotation set ID 653 created successfully with ID 14659
# Annotation for annotation set ID 653 created successfully with ID 14660
# Annotation for annotation set ID 653 created successfully with ID 14661
# Annotation for annotation set ID 653 created successfully with ID 14662
# Annotation for annotation set ID 653 created successfully with ID 14663
# Annotation for annotation set ID 653 created successfully with ID 14664
# Annotation for annotation set ID 653 created successfully with ID 14665
# Annotation for annotation set ID 653 created successfully with ID 14666
# Annotation for annotation set ID 653 created successfully with ID 14667
# Annotation for annotation set ID 653 created successfully with ID 14668
# Annotation for annotation set ID 653 created successfully with ID 14669
# Annotation for annotation set ID 653 created successfully with ID 14670
# Annotation for annotation set ID 653 created successfully with ID 14671
# Annotation for annotation set ID 653 created successfully with ID 14672
# Annotation for annotation set ID 653 created successfully with ID 14673
# Annotation for annotation set ID 653 created successfully with ID 14674
# Annotation for annotation set ID 653 created successfully with ID 14675
# Annotation for annotation set ID 653 created successfully with ID 14676
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14677
# Annotation for annotation set ID 653 created successfully with ID 14678
# Annotation for annotation set ID 653 created successfully with ID 14679
# Annotation for annotation set ID 653 created successfully with ID 14680
# Annotation for annotation set ID 653 created successfully with ID 14681
# Annotation for annotation set ID 653 created successfully with ID 14682
# Annotation for annotation set ID 653 created successfully with ID 14683
# Annotation for annotation set ID 653 created successfully with ID 14684
# Annotation for annotation set ID 653 created successfully with ID 14685
# Annotation for annotation set ID 653 created successfully with ID 14686
# Annotation for annotation set ID 653 created successfully with ID 14687
# Annotation for annotation set ID 653 created successfully with ID 14688
# Annotation for annotation set ID 653 created successfully with ID 14689
# Annotation for annotation set ID 653 created successfully with ID 14690
# Annotation for annotation set ID 653 created successfully with ID 14691
# Annotation for annotation set ID 653 created successfully with ID 14692
# Annotation for annotation set ID 653 created successfully with ID 14693
# Annotation for annotation set ID 653 created successfully with ID 14694
# Annotation for annotation set ID 653 created successfully with ID 14695
# Annotation for annotation set ID 653 created successfully with ID 14696
# Annotation for annotation set ID 653 created successfully with ID 14697
# Annotation for annotation set ID 653 created successfully with ID 14698
# Annotation for annotation set ID 653 created successfully with ID 14699
# Annotation for annotation set ID 653 created successfully with ID 14700
# Annotation for annotation set ID 653 created successfully with ID 14701
# Annotation for annotation set ID 653 created successfully with ID 14702
# Annotation for annotation set ID 653 created successfully with ID 14703
# Annotation for annotation set ID 653 created successfully with ID 14704
# Annotation for annotation set ID 653 created successfully with ID 14705
# Annotation for annotation set ID 653 created successfully with ID 14706
# Annotation for annotation set ID 653 created successfully with ID 14707
# Annotation for annotation set ID 653 created successfully with ID 14708
# Annotation for annotation set ID 653 created successfully with ID 14709
# Annotation for annotation set ID 653 created successfully with ID 14710
# Annotation for annotation set ID 653 created successfully with ID 14711
# Annotation for annotation set ID 653 created successfully with ID 14712
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 14713
# Annotation for annotation set ID 653 created successfully with ID 14714
# Annotation for annotation set ID 653 created successfully with ID 14715
# ...
# Annotation for annotation set ID 653 created successfully with ID 15148
# Annotation for annotation set ID 653 created successfully with ID 15149
# Annotation for annotation set ID 653 created successfully with ID 15150
# Annotation for annotation set ID 653 created successfully with ID 15151
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15152
# Annotation for annotation set ID 653 created successfully with ID 15153
# Annotation for annotation set ID 653 created successfully with ID 15154
# Annotation for annotation set ID 653 created successfully with ID 15155
# Annotation for annotation set ID 653 created successfully with ID 15156
# Annotation for annotation set ID 653 created successfully with ID 15157
# Annotation for annotation set ID 653 created successfully with ID 15158
# Annotation for annotation set ID 653 created successfully with ID 15159
# Annotation for annotation set ID 653 created successfully with ID 15160
# Annotation for annotation set ID 653 created successfully with ID 15161
# Annotation for annotation set ID 653 created successfully with ID 15162
# Annotation for annotation set ID 653 created successfully with ID 15163
# Annotation for annotation set ID 653 created successfully with ID 15164
# Annotation for annotation set ID 653 created successfully with ID 15165
# Annotation for annotation set ID 653 created successfully with ID 15166
# Annotation for annotation set ID 653 created successfully with ID 15167
# Annotation for annotation set ID 653 created successfully with ID 15168
# Annotation for annotation set ID 653 created successfully with ID 15169
# Annotation for annotation set ID 653 created successfully with ID 15170
# Annotation for annotation set ID 653 created successfully with ID 15171
# Annotation for annotation set ID 653 created successfully with ID 15172
# Annotation for annotation set ID 653 created successfully with ID 15173
# Annotation for annotation set ID 653 created successfully with ID 15174
# Annotation for annotation set ID 653 created successfully with ID 15175
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15176
# Annotation for annotation set ID 653 created successfully with ID 15177
# Annotation for annotation set ID 653 created successfully with ID 15178
# Annotation for annotation set ID 653 created successfully with ID 15179
# Annotation for annotation set ID 653 created successfully with ID 15180
# Annotation for annotation set ID 653 created successfully with ID 15181
# Annotation for annotation set ID 653 created successfully with ID 15182
# Annotation for annotation set ID 653 created successfully with ID 15183
# Annotation for annotation set ID 653 created successfully with ID 15184
# Annotation for annotation set ID 653 created successfully with ID 15185
# Annotation for annotation set ID 653 created successfully with ID 15186
# Annotation for annotation set ID 653 created successfully with ID 15187
# Annotation for annotation set ID 653 created successfully with ID 15188
# Annotation for annotation set ID 653 created successfully with ID 15189
# Annotation for annotation set ID 653 created successfully with ID 15190
# Annotation for annotation set ID 653 created successfully with ID 15191
# Annotation for annotation set ID 653 created successfully with ID 15192
# Annotation for annotation set ID 653 created successfully with ID 15193
# Annotation for annotation set ID 653 created successfully with ID 15194
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15195
# Annotation for annotation set ID 653 created successfully with ID 15196
# Annotation for annotation set ID 653 created successfully with ID 15197
# Annotation for annotation set ID 653 created successfully with ID 15198
# Annotation for annotation set ID 653 created successfully with ID 15199
# Annotation for annotation set ID 653 created successfully with ID 15200
# Annotation for annotation set ID 653 created successfully with ID 15201
# Annotation for annotation set ID 653 created successfully with ID 15202
# Annotation for annotation set ID 653 created successfully with ID 15203
# Annotation for annotation set ID 653 created successfully with ID 15204
# Annotation for annotation set ID 653 created successfully with ID 15205
# Annotation for annotation set ID 653 created successfully with ID 15206
# Annotation for annotation set ID 653 created successfully with ID 15207
# Annotation for annotation set ID 653 created successfully with ID 15208
# Annotation for annotation set ID 653 created successfully with ID 15209
# Annotation for annotation set ID 653 created successfully with ID 15210
# Annotation for annotation set ID 653 created successfully with ID 15211
# Annotation for annotation set ID 653 created successfully with ID 15212
# Annotation for annotation set ID 653 created successfully with ID 15213
# Annotation for annotation set ID 653 created successfully with ID 15214
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15215
# Annotation for annotation set ID 653 created successfully with ID 15216
# Annotation for annotation set ID 653 created successfully with ID 15217
# Annotation for annotation set ID 653 created successfully with ID 15218
# Annotation for annotation set ID 653 created successfully with ID 15219
# Annotation for annotation set ID 653 created successfully with ID 15220
# Annotation for annotation set ID 653 created successfully with ID 15221
# Annotation for annotation set ID 653 created successfully with ID 15222
# Annotation for annotation set ID 653 created successfully with ID 15223
# Annotation for annotation set ID 653 created successfully with ID 15224
# Annotation for annotation set ID 653 created successfully with ID 15225
# Annotation for annotation set ID 653 created successfully with ID 15226
# Annotation for annotation set ID 653 created successfully with ID 15227
# Annotation for annotation set ID 653 created successfully with ID 15228
# Annotation for annotation set ID 653 created successfully with ID 15229
# Annotation for annotation set ID 653 created successfully with ID 15230
# Annotation for annotation set ID 653 created successfully with ID 15231
# Annotation for annotation set ID 653 created successfully with ID 15232
# Annotation for annotation set ID 653 created successfully with ID 15233
# Annotation for annotation set ID 653 created successfully with ID 15234
# Annotation for annotation set ID 653 created successfully with ID 15235
# Annotation for annotation set ID 653 created successfully with ID 15236
# Annotation for annotation set ID 653 created successfully with ID 15237
# Annotation for annotation set ID 653 created successfully with ID 15238
# Annotation for annotation set ID 653 created successfully with ID 15239
# Annotation for annotation set ID 653 created successfully with ID 15240
# Annotation for annotation set ID 653 created successfully with ID 15241
# Annotation for annotation set ID 653 created successfully with ID 15242
# Annotation for annotation set ID 653 created successfully with ID 15243
# Annotation for annotation set ID 653 created successfully with ID 15244
# Annotation for annotation set ID 653 created successfully with ID 15245
# Annotation for annotation set ID 653 created successfully with ID 15246
# Annotation for annotation set ID 653 created successfully with ID 15247
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15248
# Annotation for annotation set ID 653 created successfully with ID 15249
# Annotation for annotation set ID 653 created successfully with ID 15250
# Annotation for annotation set ID 653 created successfully with ID 15251
# Annotation for annotation set ID 653 created successfully with ID 15252
# Annotation for annotation set ID 653 created successfully with ID 15253
# Annotation for annotation set ID 653 created successfully with ID 15254
# Annotation for annotation set ID 653 created successfully with ID 15255
# Annotation for annotation set ID 653 created successfully with ID 15256
# Annotation for annotation set ID 653 created successfully with ID 15257
# Annotation for annotation set ID 653 created successfully with ID 15258
# Annotation for annotation set ID 653 created successfully with ID 15259
# Annotation for annotation set ID 653 created successfully with ID 15260
# Annotation for annotation set ID 653 created successfully with ID 15261
# Annotation for annotation set ID 653 created successfully with ID 15262
# Annotation for annotation set ID 653 created successfully with ID 15263
# Annotation for annotation set ID 653 created successfully with ID 15264
# Annotation for annotation set ID 653 created successfully with ID 15265
# Annotation for annotation set ID 653 created successfully with ID 15266
# Annotation for annotation set ID 653 created successfully with ID 15267
# Annotation for annotation set ID 653 created successfully with ID 15268
# Annotation for annotation set ID 653 created successfully with ID 15269
# Annotation for annotation set ID 653 created successfully with ID 15270
# Annotation for annotation set ID 653 created successfully with ID 15271
# Annotation for annotation set ID 653 created successfully with ID 15272
# Annotation for annotation set ID 653 created successfully with ID 15273
# Annotation for annotation set ID 653 created successfully with ID 15274
# Annotation for annotation set ID 653 created successfully with ID 15275
# Annotation for annotation set ID 653 created successfully with ID 15276
# Annotation for annotation set ID 653 created successfully with ID 15277
# Annotation for annotation set ID 653 created successfully with ID 15278
# Annotation for annotation set ID 653 created successfully with ID 15279
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15280
# Annotation for annotation set ID 653 created successfully with ID 15281
# Annotation for annotation set ID 653 created successfully with ID 15282
# Annotation for annotation set ID 653 created successfully with ID 15283
# Annotation for annotation set ID 653 created successfully with ID 15284
# Annotation for annotation set ID 653 created successfully with ID 15285
# Annotation for annotation set ID 653 created successfully with ID 15286
# Annotation for annotation set ID 653 created successfully with ID 15287
# Annotation for annotation set ID 653 created successfully with ID 15288
# Annotation for annotation set ID 653 created successfully with ID 15289
# Annotation for annotation set ID 653 created successfully with ID 15290
# Annotation for annotation set ID 653 created successfully with ID 15291
# Annotation for annotation set ID 653 created successfully with ID 15292
# Annotation for annotation set ID 653 created successfully with ID 15293
# Annotation for annotation set ID 653 created successfully with ID 15294
# Annotation for annotation set ID 653 created successfully with ID 15295
# Annotation for annotation set ID 653 created successfully with ID 15296
# Annotation for annotation set ID 653 created successfully with ID 15297
# Annotation for annotation set ID 653 created successfully with ID 15298
# Annotation for annotation set ID 653 created successfully with ID 15299
# Annotation for annotation set ID 653 created successfully with ID 15300
# Annotation for annotation set ID 653 created successfully with ID 15301
# Annotation for annotation set ID 653 created successfully with ID 15302
# Annotation for annotation set ID 653 created successfully with ID 15303
# Annotation for annotation set ID 653 created successfully with ID 15304
# Annotation for annotation set ID 653 created successfully with ID 15305
# Annotation for annotation set ID 653 created successfully with ID 15306
# Annotation for annotation set ID 653 created successfully with ID 15307
# Annotation for annotation set ID 653 created successfully with ID 15308
# Annotation for annotation set ID 653 created successfully with ID 15309
# Annotation for annotation set ID 653 created successfully with ID 15310
# Annotation for annotation set ID 653 created successfully with ID 15311
# Annotation for annotation set ID 653 created successfully with ID 15312
# Annotation for annotation set ID 653 created successfully with ID 15313
# Annotation for annotation set ID 653 created successfully with ID 15314
# Annotation for annotation set ID 653 created successfully with ID 15315
# Annotation for annotation set ID 653 created successfully with ID 15316
# Annotation for annotation set ID 653 created successfully with ID 15317
# Annotation for annotation set ID 653 created successfully with ID 15318
# Annotation for annotation set ID 653 created successfully with ID 15319
# Annotation for annotation set ID 653 created successfully with ID 15320
# Annotation for annotation set ID 653 created successfully with ID 15321
# --------------------------------------------------
# Annotation for annotation set ID 653 created successfully with ID 15322
# Annotation for annotation set ID 653 created successfully with ID 15323
# Annotation for annotation set ID 653 created successfully with ID 15324
# Annotation for annotation set ID 653 created successfully with ID 15325
# Annotation for annotation set ID 653 created successfully with ID 15326
# Annotation for annotation set ID 653 created successfully with ID 15327
# Annotation for annotation set ID 653 created successfully with ID 15328
# Annotation for annotation set ID 653 created successfully with ID 15329
# Annotation for annotation set ID 653 created successfully with ID 15330
# Annotation for annotation set ID 653 created successfully with ID 15331
# Annotation for annotation set ID 653 created successfully with ID 15332
# Annotation for annotation set ID 653 created successfully with ID 15333
# Annotation for annotation set ID 653 created successfully with ID 15334
# Annotation for annotation set ID 653 created successfully with ID 15335
# Annotation for annotation set ID 653 created successfully with ID 15336
# Annotation for annotation set ID 653 created successfully with ID 15337
# Annotation for annotation set ID 653 created successfully with ID 15338
# Annotation for annotation set ID 653 created successfully with ID 15339
# Annotation for annotation set ID 653 created successfully with ID 15340
# Annotation for annotation set ID 653 created successfully with ID 15341
# Annotation for annotation set ID 653 created successfully with ID 15342
# Annotation for annotation set ID 653 created successfully with ID 15343
# Annotation for annotation set ID 653 created successfully with ID 15344
# Annotation for annotation set ID 653 created successfully with ID 15345
# Annotation for annotation set ID 653 created successfully with ID 15346
# Annotation for annotation set ID 653 created successfully with ID 15347
# Annotation for annotation set ID 653 created successfully with ID 15348
# Annotation for annotation set ID 653 created successfully with ID 15349
# Annotation for annotation set ID 653 created successfully with ID 15350
# Annotation for annotation set ID 653 created successfully with ID 15351
# Annotation for annotation set ID 653 created successfully with ID 15352
# Annotation for annotation set ID 653 created successfully with ID 15353
# Annotation for annotation set ID 653 created successfully with ID 15354
# Annotation for annotation set ID 653 created successfully with ID 15355
# Annotation for annotation set ID 653 created successfully with ID 15356
# Annotation for annotation set ID 653 created successfully with ID 15357
# Annotation for annotation set ID 653 created successfully with ID 15358
# Image set published successfully
# Annotation set published successfully
# https://iaw.ardc-hdcl-sia-iaw.cloud.edu.au/publications/image-sets/01j8nv83tg7377djm2sbpv7xtw
#         <iframe
#             width="100%"
#             height="700px"
#             src="https://iaw.ardc-hdcl-sia-iaw.cloud.edu.au/publications/image-sets/01j8nv83tg7377djm2sbpv7xtw"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
